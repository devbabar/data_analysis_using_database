# %%
import pandas as pd

# %%
import pymysql

# %%
#df=pd.read_csv('RealEstate.csv')
#df

# %%
from sqlalchemy import create_engine

# %%
#database name = houseprice
#table name = realestate
engine=create_engine('mysql+pymysql://<username>:<password>@localhost/houseprice')

# %%
table_name='realestate'
df=pd.read_sql_table(table_name,engine)
df
# Out:
#         MLS             Location      Price  Bedrooms  Bathrooms  Size  \
# 0    132842        Arroyo Grande   795000.0         3          3  2371
# 1    134364          Paso Robles   399000.0         4          3  2818
# 2    135141          Paso Robles   545000.0         4          3  3032
# 3    135712            Morro Bay   909000.0         4          4  3540
# 4    136282   Santa Maria-Orcutt   109900.0         3          1  1249
# 5    136431               Oceano   324900.0         3          3  1800
# 6    137036   Santa Maria-Orcutt   192900.0         4          2  1603
# 7    137090   Santa Maria-Orcutt   215000.0         3          2  1450
# 8    137159            Morro Bay   999000.0         4          3  3360
# 9    137570           Atascadero   319000.0         3          2  1323
# 10   138053   Santa Maria-Orcutt   350000.0         3          2  1750
# 11   138730   Santa Maria-Orcutt   249000.0         3          2  1400
# ...

# %%
# table name = realestate
df2=pd.read_sql_query('SELECT Location, Price FROM realestate;',engine)

# %%
df2
# Out:
#                 Location      Price
# 0          Arroyo Grande   795000.0
# 1            Paso Robles   399000.0
# 2            Paso Robles   545000.0
# 3              Morro Bay   909000.0
# 4     Santa Maria-Orcutt   109900.0
# 5                 Oceano   324900.0
# 6     Santa Maria-Orcutt   192900.0
# 7     Santa Maria-Orcutt   215000.0
# 8              Morro Bay   999000.0
# 9             Atascadero   319000.0
# 10    Santa Maria-Orcutt   350000.0
# 11    Santa Maria-Orcutt   249000.0
# 12         Arroyo Grande   299000.0
# 13    Santa Maria-Orcutt   235900.0
# 14    Santa Maria-Orcutt   348000.0
# 15           Paso Robles   314000.0
# 16            Los Alamos   399000.0
# 17            San Miguel   599000.0
# 18           Paso Robles   299000.0
# 19       San Luis Obispo   425000.0
# 20             Morro Bay  1100000.0
# 21               Cayucos  1500000.0
# 22    Santa Maria-Orcutt   110000.0
# 23    Santa Maria-Orcutt   200000.0
# 24    Santa Maria-Orcutt   134900.0
# ...

# %%
df['Location'].value_counts()
# Out:
# Santa Maria-Orcutt     265
# Paso Robles             85
# Atascadero              58
# Nipomo                  34
# Arroyo Grande           28
# Lompoc                  26
# Los Osos                21
# Grover Beach            20
#  Paso Robles            15
# San Miguel              14
# San Luis Obispo         14
#  Santa Maria-Orcutt     13
# Morro Bay               13
#  Cambria                12
#  Arroyo Grande          12
# Pismo Beach             12
# Buellton                12
# Templeton               11
# Oceano                  10
#  Atascadero             10
# Cambria                  9
#  Pismo Beach             8
# Solvang                  8
# Coalinga                 7
#  Los Osos                6
# Santa Ynez               5
#  Morro Bay               4
# Guadalupe                4
# Avila Beach              3
#  San Luis Obispo         3
# Bradley                  3
# Out Of Area              3
#  Nipomo                  3
# Soledad                  3
# ...

# %%
a=df[['Location','Price']]
a
# Out:
#                 Location      Price
# 0          Arroyo Grande   795000.0
# 1            Paso Robles   399000.0
# 2            Paso Robles   545000.0
# 3              Morro Bay   909000.0
# 4     Santa Maria-Orcutt   109900.0
# 5                 Oceano   324900.0
# 6     Santa Maria-Orcutt   192900.0
# 7     Santa Maria-Orcutt   215000.0
# 8              Morro Bay   999000.0
# 9             Atascadero   319000.0
# 10    Santa Maria-Orcutt   350000.0
# 11    Santa Maria-Orcutt   249000.0
# 12         Arroyo Grande   299000.0
# 13    Santa Maria-Orcutt   235900.0
# 14    Santa Maria-Orcutt   348000.0
# 15           Paso Robles   314000.0
# 16            Los Alamos   399000.0
# 17            San Miguel   599000.0
# 18           Paso Robles   299000.0
# 19       San Luis Obispo   425000.0
# 20             Morro Bay  1100000.0
# 21               Cayucos  1500000.0
# 22    Santa Maria-Orcutt   110000.0
# 23    Santa Maria-Orcutt   200000.0
# 24    Santa Maria-Orcutt   134900.0
# ...

# %%
a.Location
# Out:
# 0      False
# 1       True
# 2       True
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15      True
# 16     False
# 17     False
# 18      True
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 751    False
# 752    False
# 753    False
# 754    False
# 755    False
# 756    False
# 757    False
# 758    False
# 759    False
# 760    False
# 761    False
# 762    False
# 763    False
# 764    False
# 765    False
# 766    False
# 767    False
# 768    False
# 769    False
# 770    False
# 771    False
# 772    False
# 773    False
# 774    False
# 775    False
# 776    False
# 777    False
# 778    False
# 779    False
# 780    False
# Name: Location, Length: 781, dtype: bool
